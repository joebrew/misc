# %%
from pandas import *
import pandas
import numpy as np
import matplotlib.pyplot as plt

def side_by_side(*objs, **kwds):
    from pandas.core.common import adjoin
    space = kwds.get('space', 4)
    reprs = [repr(obj).split('\n') for obj in objs]
    print adjoin(space, *reprs)

plt.rc('figure', figsize=(10, 6))
#pandas.set_printoptions(notebook_repr_html=False)

# %%
plot(arange(10))

# %% [markdown]
# Series
# ======

# %%
# Create a simple series
labels = ['a', 'b', 'c', 'd', 'e']
s = Series(randn(5), index=labels) # randn is normally distributed data
s
# Out:
# a    0.915217
# b   -1.138429
# c   -1.079603
# d   -1.147663
# e    1.461794
# dtype: float64

# %%
'b' in s
# Out:
# True

# %%
s.index
# Out:
# Index([u'a', u'b', u'c', u'd', u'e'], dtype='object')

# %%
s['b'] # looks up value at location b
# Out:
# -1.1384293510412358

# %%
s
# Out:
# a    0.915217
# b   -1.138429
# c   -1.079603
# d   -1.147663
# e    1.461794
# dtype: float64

# %%
mapping = s.to_dict() # converts series to a dict
mapping
# Out:
# {'a': 0.91521675594295293,
#  'b': -1.1384293510412358,
#  'c': -1.0796030795718905,
#  'd': -1.1476631071970202,
#  'e': 1.4617937006820372}

# %%
s = Series(mapping) # convert dict to a series
s
# Out:
# a    0.915217
# b   -1.138429
# c   -1.079603
# d   -1.147663
# e    1.461794
# dtype: float64

# %%
s[:3]

# %%
x = Series(mapping, index = ['b', 'e', 'a', 'd']) # get the specified values at index letters, throw away rest
x
# Out:
# b   -1.138429
# e    1.461794
# a    0.915217
# d   -1.147663
# dtype: float64

# %%
s.index
# Out:
# Index([u'a', u'b', u'c', u'd', u'e'], dtype='object')

# %%
arr = randn(5) # create an array of 5 random numbers
arr
arr[:3] # slice the array
# Out:
# array([-0.15772364, -2.38811453,  1.03339198])

# %% [markdown]
# DataFrame: 2D collection of Series
# ==================================

# %%
df = DataFrame({'a': np.random.randn(6),
                'b': ['foo', 'bar'] * 3,
                'c': np.random.randn(6)})
df
# Out:
#           a    b         c
# 0  0.048499  foo -1.318343
# 1  1.264303  bar -0.648634
# 2  1.044777  foo  0.047308
# 3  0.445813  bar -1.500808
# 4 -0.253577  foo  1.526277
# 5  1.245576  bar  0.270447
#
# [6 rows x 3 columns]

# %%
df['b'] #  get just one column
# columns use square brackets, rows do not
# you can't slice rows with brackets
# Out:
# 0    foo
# 1    bar
# 2    foo
# 3    bar
# 4    foo
# 5    bar
# Name: b, dtype: object

# %%
df['d'] = range(6) # create new column
# Out:
#           a    b         c  d
# 0  0.048499  foo -1.318343  0
# 1  1.264303  bar -0.648634  1
# 2  1.044777  foo  0.047308  2
# 3  0.445813  bar -1.500808  3
# 4 -0.253577  foo  1.526277  4
# 5  1.245576  bar  0.270447  5
#
# [6 rows x 4 columns]

# %%
df.xs(0) # returns the 0th row as a series, with column labels as index
# Out:
# a    0.04849938
# b           foo
# c     -1.318343
# d             0
# Name: 0, dtype: object

# %%
#df.ix # the label indexing facility
df.ix[0] # first row
df.ix[2] # third row
df.ix[2, 'b'] # third row at b
df.ix[2:4, 'b'] # slice of b column from position 2 to 4
df.ix[2:4, ['b', 'c']] # slice of b and c from position 2 to 4
# Out:
#      b         c
# 2  foo  0.047308
# 3  bar -1.500808
# 4  foo  1.526277
#
# [3 rows x 2 columns]

# %%
# select out the data where c column is greater than 0
df['c'] > 0
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# 5     True
# Name: c, dtype: bool

# %%
df.ix[df['c'] > 0] # subset the whole dataframe that way
# Out:
#           a    b         c  d
# 2  1.044777  foo  0.047308  2
# 4 -0.253577  foo  1.526277  4
# 5  1.245576  bar  0.270447  5
#
# [3 rows x 4 columns]

# %%
df[df['c'] > 0] # same thing
# Out:
#           a    b         c  d
# 2  1.044777  foo  0.047308  2
# 4 -0.253577  foo  1.526277  4
# 5  1.245576  bar  0.270447  5
#
# [3 rows x 4 columns]

# %%
df.index

# %%
df.columns

# %%
df = DataFrame({'a': np.random.randn(6),
                'b': ['foo', 'bar'] * 3,
                'c': np.random.randn(6)},
               index=DateRange('1/1/2000', periods=6)) # generates a date index
df
# Out:
#                    a    b         c
# 2000-01-03  0.103450  foo -0.631737
# 2000-01-04  0.293137  bar  2.118575
# 2000-01-05  0.677706  foo -1.635007
# 2000-01-06 -0.522864  bar  0.697185
# 2000-01-07 -1.013268  foo -0.503434
# 2000-01-10  1.776909  bar -0.432541
#
# [6 rows x 3 columns]

# %%
df = DataFrame({'a': np.random.randn(6),
                'b': ['foo', 'bar'] * 3,
                'c': np.random.randn(6)},
               columns=['a', 'b', 'c', 'd']) # add column d, which isn't in the dictionary, so it'll be NaN
df
# Out:
#           a    b         c    d
# 0 -0.258668  foo -1.207222  NaN
# 1  0.537939  bar  0.298325  NaN
# 2 -2.039723  foo -0.518180  NaN
# 3 -0.921665  bar  1.711102  NaN
# 4 -0.340848  foo -1.698284  NaN
# 5  0.203670  bar -0.307569  NaN
#
# [6 rows x 4 columns]

# %%
# are things null?
isnull(s)
notnull(s)
s[notnull(s)] # keep only s for which its not null
# Out:
# a    0.915217
# b   -1.138429
# c   -1.079603
# d   -1.147663
# e    1.461794
# dtype: float64

# %%
# Out:
# array([-2.38312638,  0.10343259, -0.63078716])

# %% [markdown]
# Creation from nested dicts
# --------------------------
#
# These arise naturally in Python code

# %%
# Nested dicts
data = {}
for col in ['foo', 'bar', 'baz']:
    for row in ['a', 'b', 'c', 'd']:
        data.setdefault(col, {})[row] = randn()
data
# Out:
# {'bar': {'a': -1.0653362879962287,
#   'b': 0.411132359734763,
#   'c': -0.8119104630575344,
#   'd': 1.3936925785511827},
#  'baz': {'a': -0.417034562330512,
#   'b': -1.2402104944607568,
#   'c': -0.8517376075377654,
#   'd': -1.6269979565963675},
#  'foo': {'a': 0.3119673209151941,
#   'b': -0.5032186413504838,
#   'c': 0.6624502654777521,
#   'd': 0.27553971295766455}}

# %%
DataFrame(data)
# Out:
#         bar       baz       foo
# a -1.065336 -0.417035  0.311967
# b  0.411132 -1.240210 -0.503219
# c -0.811910 -0.851738  0.662450
# d  1.393693 -1.626998  0.275540
#
# [4 rows x 3 columns]

# %%
# Delte foo c
del data['foo']['c']

# %%
DataFrame(data)
# Out:
#         bar       baz       foo
# a -1.065336 -0.417035  0.311967
# b  0.411132 -1.240210 -0.503219
# c -0.811910 -0.851738       NaN
# d  1.393693 -1.626998  0.275540
#
# [4 rows x 3 columns]

# %% [markdown]
# Data alignment
# ==============

# %%
close_px = read_csv('PandasTutorialFiles/stock_data.csv', index_col=0, parse_dates=True) #

# %%
close_px
# Out:
#                AA    AAPL     GE     IBM    JNJ   MSFT    PEP      SPX    XOM
# 2007-10-29  37.41  185.09  34.46  106.78  57.13  31.78  65.67  1540.98  85.51
# 2007-10-30  36.43  187.00  34.39  106.15  56.99  32.70  65.80  1531.02  83.25
# 2007-10-31  36.79  189.95  34.97  108.01  57.30  33.84  65.69  1549.38  84.03
# 2007-11-01  35.22  187.44  34.27  105.72  56.85  34.07  64.51  1508.44  80.84
# 2007-11-02  35.83  187.87  34.27  106.59  56.95  34.07  65.03  1509.65  80.32
# 2007-11-05  35.22  186.18  34.15  105.48  56.70  33.77  64.84  1502.17  80.07
# 2007-11-06  35.84  191.79  34.14  105.27  56.80  33.47  65.49  1520.27  82.56
# 2007-11-07  34.76  186.30  33.20  103.69  56.19  32.65  64.46  1475.62  79.96
# 2007-11-08  35.00  175.47  33.15   99.05  56.79  31.94  65.50  1474.77  82.00
# 2007-11-09  34.47  165.37  32.61   93.58  57.29  31.01  65.48  1453.70  79.64
# 2007-11-12  33.33  153.76  32.50   94.70  58.30  30.69  64.67  1439.18  77.52
# ...

# %%
close_px
# Out:
#                AA    AAPL     GE     IBM    JNJ   MSFT    PEP      SPX    XOM
# 2007-10-29  37.41  185.09  34.46  106.78  57.13  31.78  65.67  1540.98  85.51
# 2007-10-30  36.43  187.00  34.39  106.15  56.99  32.70  65.80  1531.02  83.25
# 2007-10-31  36.79  189.95  34.97  108.01  57.30  33.84  65.69  1549.38  84.03
# 2007-11-01  35.22  187.44  34.27  105.72  56.85  34.07  64.51  1508.44  80.84
# 2007-11-02  35.83  187.87  34.27  106.59  56.95  34.07  65.03  1509.65  80.32
# 2007-11-05  35.22  186.18  34.15  105.48  56.70  33.77  64.84  1502.17  80.07
# 2007-11-06  35.84  191.79  34.14  105.27  56.80  33.47  65.49  1520.27  82.56
# 2007-11-07  34.76  186.30  33.20  103.69  56.19  32.65  64.46  1475.62  79.96
# 2007-11-08  35.00  175.47  33.15   99.05  56.79  31.94  65.50  1474.77  82.00
# 2007-11-09  34.47  165.37  32.61   93.58  57.29  31.01  65.48  1453.70  79.64
# 2007-11-12  33.33  153.76  32.50   94.70  58.30  30.69  64.67  1439.18  77.52
# ...

# %%
s1 = close_px['AAPL'][-20:]
s2 = close_px['AAPL'][-25:-10]
side_by_side(s1, s2)
# Out:
# 2011-09-19    411.63          2011-09-12    379.94
# 2011-09-20    413.45          2011-09-13    384.62
# 2011-09-21    412.14          2011-09-14    389.30
# 2011-09-22    401.82          2011-09-15    392.96
# 2011-09-23    404.30          2011-09-16    400.50
# 2011-09-26    403.17          2011-09-19    411.63
# 2011-09-27    399.26          2011-09-20    413.45
# 2011-09-28    397.01          2011-09-21    412.14
# 2011-09-29    390.57          2011-09-22    401.82
# 2011-09-30    381.32          2011-09-23    404.30
# 2011-10-03    374.60          2011-09-26    403.17
# 2011-10-04    372.50          2011-09-27    399.26
# 2011-10-05    378.25          2011-09-28    397.01
# 2011-10-06    377.37          2011-09-29    390.57
# 2011-10-07    369.80          2011-09-30    381.32
# 2011-10-10    388.81          Name: AAPL, dtype: float64
# 2011-10-11    400.29
# 2011-10-12    402.19
# 2011-10-13    408.43
# 2011-10-14    422.00
# Name: AAPL, dtype: float64

# %%
s1 + s2
# Out:
# 2011-09-12       NaN
# 2011-09-13       NaN
# 2011-09-14       NaN
# 2011-09-15       NaN
# 2011-09-16       NaN
# 2011-09-19    823.26
# 2011-09-20    826.90
# 2011-09-21    824.28
# 2011-09-22    803.64
# 2011-09-23    808.60
# 2011-09-26    806.34
# 2011-09-27    798.52
# 2011-09-28    794.02
# 2011-09-29    781.14
# 2011-09-30    762.64
# 2011-10-03       NaN
# 2011-10-04       NaN
# 2011-10-05       NaN
# 2011-10-06       NaN
# 2011-10-07       NaN
# 2011-10-10       NaN
# 2011-10-11       NaN
# 2011-10-12       NaN
# 2011-10-13       NaN
# 2011-10-14       NaN
# Name: AAPL, dtype: float64

# %%
df = close_px.ix[-10:, :3]
df
# Out:
#                AA    AAPL     GE
# 2011-10-03   8.90  374.60  14.69
# 2011-10-04   9.12  372.50  14.86
# 2011-10-05   9.37  378.25  15.27
# 2011-10-06   9.88  377.37  15.53
# 2011-10-07   9.71  369.80  15.50
# 2011-10-10  10.09  388.81  16.14
# 2011-10-11  10.30  400.29  16.14
# 2011-10-12  10.05  402.19  16.40
# 2011-10-13  10.10  408.43  16.22
# 2011-10-14  10.26  422.00  16.60
#
# [10 rows x 3 columns]

# %%
side_by_side(s1.reindex(s2.index), s2) # conform series 1 to the index of series 2
# Out:
# 2011-09-12       NaN          2011-09-12    379.94
# 2011-09-13       NaN          2011-09-13    384.62
# 2011-09-14       NaN          2011-09-14    389.30
# 2011-09-15       NaN          2011-09-15    392.96
# 2011-09-16       NaN          2011-09-16    400.50
# 2011-09-19    411.63          2011-09-19    411.63
# 2011-09-20    413.45          2011-09-20    413.45
# 2011-09-21    412.14          2011-09-21    412.14
# 2011-09-22    401.82          2011-09-22    401.82
# 2011-09-23    404.30          2011-09-23    404.30
# 2011-09-26    403.17          2011-09-26    403.17
# 2011-09-27    399.26          2011-09-27    399.26
# 2011-09-28    397.01          2011-09-28    397.01
# 2011-09-29    390.57          2011-09-29    390.57
# 2011-09-30    381.32          2011-09-30    381.32
# Name: AAPL, dtype: float64    Name: AAPL, dtype: float64

# %%
b, c  = s1.align(s2, join='inner')
side_by_side(b, c)
# Out:
# 2011-09-19    411.63          2011-09-19    411.63
# 2011-09-20    413.45          2011-09-20    413.45
# 2011-09-21    412.14          2011-09-21    412.14
# 2011-09-22    401.82          2011-09-22    401.82
# 2011-09-23    404.30          2011-09-23    404.30
# 2011-09-26    403.17          2011-09-26    403.17
# 2011-09-27    399.26          2011-09-27    399.26
# 2011-09-28    397.01          2011-09-28    397.01
# 2011-09-29    390.57          2011-09-29    390.57
# 2011-09-30    381.32          2011-09-30    381.32
# Name: AAPL, dtype: float64    Name: AAPL, dtype: float64

# %%
b, c  = s1.align(s2, join='outer')
side_by_side(b, c)
# Out:
# 2011-09-12       NaN          2011-09-12    379.94
# 2011-09-13       NaN          2011-09-13    384.62
# 2011-09-14       NaN          2011-09-14    389.30
# 2011-09-15       NaN          2011-09-15    392.96
# 2011-09-16       NaN          2011-09-16    400.50
# 2011-09-19    411.63          2011-09-19    411.63
# 2011-09-20    413.45          2011-09-20    413.45
# 2011-09-21    412.14          2011-09-21    412.14
# 2011-09-22    401.82          2011-09-22    401.82
# 2011-09-23    404.30          2011-09-23    404.30
# 2011-09-26    403.17          2011-09-26    403.17
# 2011-09-27    399.26          2011-09-27    399.26
# 2011-09-28    397.01          2011-09-28    397.01
# 2011-09-29    390.57          2011-09-29    390.57
# 2011-09-30    381.32          2011-09-30    381.32
# 2011-10-03    374.60          2011-10-03       NaN
# 2011-10-04    372.50          2011-10-04       NaN
# 2011-10-05    378.25          2011-10-05       NaN
# ...

# %%
b, c  = s1.align(s2, join='right')
side_by_side(b, c)
# Out:
# 2011-09-12       NaN          2011-09-12    379.94
# 2011-09-13       NaN          2011-09-13    384.62
# 2011-09-14       NaN          2011-09-14    389.30
# 2011-09-15       NaN          2011-09-15    392.96
# 2011-09-16       NaN          2011-09-16    400.50
# 2011-09-19    411.63          2011-09-19    411.63
# 2011-09-20    413.45          2011-09-20    413.45
# 2011-09-21    412.14          2011-09-21    412.14
# 2011-09-22    401.82          2011-09-22    401.82
# 2011-09-23    404.30          2011-09-23    404.30
# 2011-09-26    403.17          2011-09-26    403.17
# 2011-09-27    399.26          2011-09-27    399.26
# 2011-09-28    397.01          2011-09-28    397.01
# 2011-09-29    390.57          2011-09-29    390.57
# 2011-09-30    381.32          2011-09-30    381.32
# Name: AAPL, dtype: float64    Name: AAPL, dtype: float64

# %%
df = close_px.ix[-10:, ['AAPL', 'IBM', 'MSFT']]
df
# Out:
#               AAPL     IBM   MSFT
# 2011-10-03  374.60  173.29  24.53
# 2011-10-04  372.50  174.74  25.34
# 2011-10-05  378.25  176.85  25.89
# 2011-10-06  377.37  181.69  26.34
# 2011-10-07  369.80  182.39  26.25
# 2011-10-10  388.81  186.62  26.94
# 2011-10-11  400.29  185.00  27.00
# 2011-10-12  402.19  186.12  26.96
# 2011-10-13  408.43  186.82  27.18
# 2011-10-14  422.00  190.53  27.27
#
# [10 rows x 3 columns]

# %%
df2 = df.ix[::2, ['IBM', 'MSFT']]
side_by_side(df, df2)
# Out:
#               AAPL     IBM   MSFT                   IBM   MSFT
# 2011-10-03  374.60  173.29  24.53    2011-10-03  173.29  24.53
# 2011-10-04  372.50  174.74  25.34    2011-10-05  176.85  25.89
# 2011-10-05  378.25  176.85  25.89    2011-10-07  182.39  26.25
# 2011-10-06  377.37  181.69  26.34    2011-10-11  185.00  27.00
# 2011-10-07  369.80  182.39  26.25    2011-10-13  186.82  27.18
# 2011-10-10  388.81  186.62  26.94
# 2011-10-11  400.29  185.00  27.00    [5 rows x 2 columns]
# 2011-10-12  402.19  186.12  26.96
# 2011-10-13  408.43  186.82  27.18
# 2011-10-14  422.00  190.53  27.27
#
# [10 rows x 3 columns]

# %%
df + df2
# Out:
#             AAPL     IBM   MSFT
# 2011-10-03   NaN  346.58  49.06
# 2011-10-04   NaN     NaN    NaN
# 2011-10-05   NaN  353.70  51.78
# 2011-10-06   NaN     NaN    NaN
# 2011-10-07   NaN  364.78  52.50
# 2011-10-10   NaN     NaN    NaN
# 2011-10-11   NaN  370.00  54.00
# 2011-10-12   NaN     NaN    NaN
# 2011-10-13   NaN  373.64  54.36
# 2011-10-14   NaN     NaN    NaN
#
# [10 rows x 3 columns]

# %%
b, c = df.align(df2, join='inner')
side_by_side(b, c)
# Out:
#                IBM   MSFT                   IBM   MSFT
# 2011-10-03  173.29  24.53    2011-10-03  173.29  24.53
# 2011-10-05  176.85  25.89    2011-10-05  176.85  25.89
# 2011-10-07  182.39  26.25    2011-10-07  182.39  26.25
# 2011-10-11  185.00  27.00    2011-10-11  185.00  27.00
# 2011-10-13  186.82  27.18    2011-10-13  186.82  27.18
#
# [5 rows x 2 columns]         [5 rows x 2 columns]

# %% [markdown]
# Transposing: no copy if all columns are same type
# -------------------------------------------------

# %%
df[:5].T
# Out:
#       2011-10-03  2011-10-04  2011-10-05  2011-10-06  2011-10-07
# AAPL      374.60      372.50      378.25      377.37      369.80
# IBM       173.29      174.74      176.85      181.69      182.39
# MSFT       24.53       25.34       25.89       26.34       26.25
#
# [3 rows x 5 columns]

# %% [markdown]
# Columns can be any type
# -----------------------

# %%
n = 10
foo = DataFrame(index=range(n))
foo['floats'] = np.random.randn(n)
foo['ints'] = np.arange(n)
foo['strings'] = ['foo', 'bar'] * (n / 2)
foo['bools'] = foo['floats'] > 0
foo['objects'] = DateRange('1/1/2000', periods=n)
foo
# Out:
#      floats  ints strings  bools    objects
# 0  0.458069     0     foo   True 2000-01-03
# 1  0.588963     1     bar   True 2000-01-04
# 2 -0.755589     2     foo  False 2000-01-05
# 3 -1.266982     3     bar  False 2000-01-06
# 4  0.718974     4     foo   True 2000-01-07
# 5 -0.259115     5     bar  False 2000-01-10
# 6 -0.638270     6     foo  False 2000-01-11
# 7  1.082580     7     bar   True 2000-01-12
# 8  1.545648     8     foo   True 2000-01-13
# 9  0.703898     9     bar   True 2000-01-14
#
# [10 rows x 5 columns]

# %%
foo.dtypes
# Out:
# floats            float64
# ints                int64
# strings            object
# bools                bool
# objects    datetime64[ns]
# dtype: object

# %% [markdown]
# N.B. transposing is not roundtrippable in this case (column-oriented data structure)

# %%
foo.T.T
# Out:
#       floats ints strings  bools    objects
# 0   0.458069    0     foo   True 2000-01-03
# 1  0.5889632    1     bar   True 2000-01-04
# 2  -0.755589    2     foo  False 2000-01-05
# 3  -1.266982    3     bar  False 2000-01-06
# 4  0.7189735    4     foo   True 2000-01-07
# 5 -0.2591154    5     bar  False 2000-01-10
# 6 -0.6382701    6     foo  False 2000-01-11
# 7    1.08258    7     bar   True 2000-01-12
# 8   1.545648    8     foo   True 2000-01-13
# 9  0.7038982    9     bar   True 2000-01-14
#
# [10 rows x 5 columns]

# %%
foo.T.T.dtypes
# Out:
# floats     object
# ints       object
# strings    object
# bools      object
# objects    object
# dtype: object

# %% [markdown]
# Function application
# ====================
#
# You can apply arbitrary functions to the rows or columns of a DataFrame

# %%
df.apply(np.mean)
# Out:
# AAPL    389.424
# IBM     182.405
# MSFT     26.370
# dtype: float64

# %%
df.apply(np.mean, axis=1)
# Out:
# 2011-10-03    190.806667
# 2011-10-04    190.860000
# 2011-10-05    193.663333
# 2011-10-06    195.133333
# 2011-10-07    192.813333
# 2011-10-10    200.790000
# 2011-10-11    204.096667
# 2011-10-12    205.090000
# 2011-10-13    207.476667
# 2011-10-14    213.266667
# dtype: float64

# %%
df.mean() # computes mean of columns
# Out:
# AAPL    389.424
# IBM     182.405
# MSFT     26.370
# dtype: float64

# %%
df.mean(1) # computes mean of rows
# Out:
# 2011-10-03    190.806667
# 2011-10-04    190.860000
# 2011-10-05    193.663333
# 2011-10-06    195.133333
# 2011-10-07    192.813333
# 2011-10-10    200.790000
# 2011-10-11    204.096667
# 2011-10-12    205.090000
# 2011-10-13    207.476667
# 2011-10-14    213.266667
# dtype: float64

# %% [markdown]
# You can get as fancy as you want

# %%
close_px
# Out:
#                AA    AAPL     GE     IBM    JNJ   MSFT    PEP      SPX    XOM
# 2007-10-29  37.41  185.09  34.46  106.78  57.13  31.78  65.67  1540.98  85.51
# 2007-10-30  36.43  187.00  34.39  106.15  56.99  32.70  65.80  1531.02  83.25
# 2007-10-31  36.79  189.95  34.97  108.01  57.30  33.84  65.69  1549.38  84.03
# 2007-11-01  35.22  187.44  34.27  105.72  56.85  34.07  64.51  1508.44  80.84
# 2007-11-02  35.83  187.87  34.27  106.59  56.95  34.07  65.03  1509.65  80.32
# 2007-11-05  35.22  186.18  34.15  105.48  56.70  33.77  64.84  1502.17  80.07
# 2007-11-06  35.84  191.79  34.14  105.27  56.80  33.47  65.49  1520.27  82.56
# 2007-11-07  34.76  186.30  33.20  103.69  56.19  32.65  64.46  1475.62  79.96
# 2007-11-08  35.00  175.47  33.15   99.05  56.79  31.94  65.50  1474.77  82.00
# 2007-11-09  34.47  165.37  32.61   93.58  57.29  31.01  65.48  1453.70  79.64
# 2007-11-12  33.33  153.76  32.50   94.70  58.30  30.69  64.67  1439.18  77.52
# ...

# %%
close_px.AAPL # apple column only
# Out:
# 2007-10-29    185.09
# 2007-10-30    187.00
# 2007-10-31    189.95
# 2007-11-01    187.44
# 2007-11-02    187.87
# 2007-11-05    186.18
# 2007-11-06    191.79
# 2007-11-07    186.30
# 2007-11-08    175.47
# 2007-11-09    165.37
# 2007-11-12    153.76
# 2007-11-13    169.96
# 2007-11-14    166.11
# 2007-11-15    164.30
# 2007-11-16    166.39
# ...
# 2011-09-26    403.17
# 2011-09-27    399.26
# 2011-09-28    397.01
# 2011-09-29    390.57
# 2011-09-30    381.32
# 2011-10-03    374.60
# 2011-10-04    372.50
# 2011-10-05    378.25
# 2011-10-06    377.37
# 2011-10-07    369.80
# 2011-10-10    388.81
# 2011-10-11    400.29
# 2011-10-12    402.19
# 2011-10-13    408.43
# 2011-10-14    422.00
# Name: AAPL, Length: 1000

# %%
close_px.AAPL.idxmax() # get id for max
# Out:
# Timestamp('2011-10-14 00:00:00', tz=None)

# %%
# Function set date on which maximum value for a column occurred
def peak_date(series):
    return series.idxmax()
close_px.apply(peak_date)
# returns a series indexed by the column names of each dataframe
# give the date of that columns max
# Out:
# AA     2008-05-19
# AAPL   2011-10-14
# GE     2007-10-31
# IBM    2011-10-14
# JNJ    2011-07-07
# MSFT   2007-11-01
# PEP    2008-01-10
# SPX    2007-10-31
# XOM    2008-05-20
# dtype: datetime64[ns]

# %%
#df.apply(lambda x: x.max() - x.min()) # np.ptp

# %%
np.log(close_px)
# Out:
#                   AA      AAPL        GE       IBM       JNJ      MSFT  \
# 2007-10-29  3.621938  5.220842  3.539799  4.670771  4.045329  3.458837
# 2007-10-30  3.595393  5.231109  3.537766  4.664853  4.042876  3.487375
# 2007-10-31  3.605226  5.246761  3.554491  4.682224  4.048301  3.521644
# 2007-11-01  3.561614  5.233459  3.534270  4.660794  4.040416  3.528417
# 2007-11-02  3.578786  5.235750  3.534270  4.668990  4.042174  3.528417
# 2007-11-05  3.561614  5.226714  3.530763  4.658521  4.037774  3.519573
# 2007-11-06  3.579065  5.256401  3.530470  4.656528  4.039536  3.510650
# 2007-11-07  3.548467  5.227358  3.502550  4.641406  4.028739  3.485845
# 2007-11-08  3.555348  5.167468  3.501043  4.595625  4.039360  3.463859
# 2007-11-09  3.540089  5.108185  3.484619  4.538817  4.048126  3.434310
# 2007-11-12  3.506458  5.035393  3.481240  4.550714  4.065602  3.423937
# 2007-11-13  3.527536  5.135563  3.505858  4.587719  4.080584  3.459152
# ...

# %% [markdown]
# Plotting
# ========
#
# Some basic plotting integration with matplotlib in Series / DataFrame

# %%
close_px[['AAPL', 'IBM', 'MSFT', 'XOM']]#.plot()
# Out:
#               AAPL     IBM   MSFT    XOM
# 2007-10-29  185.09  106.78  31.78  85.51
# 2007-10-30  187.00  106.15  32.70  83.25
# 2007-10-31  189.95  108.01  33.84  84.03
# 2007-11-01  187.44  105.72  34.07  80.84
# 2007-11-02  187.87  106.59  34.07  80.32
# 2007-11-05  186.18  105.48  33.77  80.07
# 2007-11-06  191.79  105.27  33.47  82.56
# 2007-11-07  186.30  103.69  32.65  79.96
# 2007-11-08  175.47   99.05  31.94  82.00
# 2007-11-09  165.37   93.58  31.01  79.64
# 2007-11-12  153.76   94.70  30.69  77.52
# 2007-11-13  169.96   98.27  31.79  79.67
# 2007-11-14  166.11   96.56  31.30  79.15
# 2007-11-15  164.30   96.71  31.14  77.48
# 2007-11-16  166.39   97.82  31.44  78.04
# 2007-11-19  163.95   95.42  31.32  77.13
# 2007-11-20  168.85   96.54  31.90  80.53
# 2007-11-21  168.46   95.42  31.57  79.82
# 2007-11-23  171.54   97.13  31.46  80.96
# 2007-11-26  172.54   95.19  30.41  78.57
# 2007-11-27  174.81   96.92  30.49  79.21
# 2007-11-28  180.22  100.23  31.08  80.62
# ...

# %%
close_px[['AAPL', 'IBM', 'MSFT', 'XOM']].plot()

# %%
rets.ix[-1] # last row only
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-2cf4f8fc1aa8> in <module>()
# ----> 1 rets.ix[-1] # last row only
#
# NameError: name 'rets' is not defined

# %%
close_px.ix[-1].plot(kind='bar')
title('Prices on %s' % close_px.index[-1])
axhline(0)

# %% [markdown]
# Hierarchical indexing
# ---------------------

# %%
index = MultiIndex(levels=[['foo', 'bar', 'baz', 'qux'],
                                   ['one', 'two', 'three']],
                           labels=[[0, 0, 0, 1, 1, 2, 2, 3, 3, 3],
                                   [0, 1, 2, 0, 1, 1, 2, 0, 1, 2]])
hdf = DataFrame(np.random.randn(10, 3), index=index,
                columns=['A', 'B', 'C'])
hdf

# %%
hdf.ix['foo']

# %%
hdf.ix['foo'] = 0
hdf

# %%
hdf.ix['foo', 'three']

# %% [markdown]
# Stacking and unstacking
# -----------------------

# %%
tuples = zip(*[['bar', 'bar', 'baz', 'baz',
                'foo', 'foo', 'qux', 'qux'],
               ['one', 'two', 'one', 'two',
                'one', 'two', 'one', 'two']])
index = MultiIndex.from_tuples(tuples)
columns = MultiIndex.from_tuples([('A', 'cat'), ('B', 'dog'),
                                  ('B', 'cat'), ('A', 'dog')])
df = DataFrame(randn(8, 4), index=index, columns=columns)
df

# %%
df2 = df.ix[[0, 1, 2, 4, 5, 7]]
df2

# %%
df.unstack()['B']

# %% [markdown]
# GroupBy
# =======

# %%
df = DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                       'foo', 'bar', 'foo', 'foo'],
                'B' : ['one', 'one', 'two', 'three',
                       'two', 'two', 'one', 'three'],
                'C' : np.random.randn(8),
                'D' : np.random.randn(8)})
df

# %%
for key, group in df.groupby('A'):
    print key
    print group

# %%
df.groupby('A')['C'].describe().T

# %%
df.groupby('A').mean()

# %%
for key, group in df.groupby('A'):
    print key
    print group

# %%
df.groupby(['A', 'B']).mean()

# %%
df.groupby(['A', 'B'], as_index=False).mean()

# %% [markdown]
# GroupBy example: linear regression by group
# -------------------------------------------

# %%
import scikits.statsmodels.api as sm
rets = close_px / close_px.shift(1) - 1

def get_beta(rets):
    rets = rets.dropna()
    rets['intercept'] = 1.
    model = sm.OLS(rets['MSFT'], rets.ix[:, ['AAPL', 'intercept']]).fit()
    return model.params

get_beta(rets)

# %%
grouped = rets.groupby([lambda x: x.year, lambda x: x.month])
beta_by_ym = grouped.apply(get_beta)
beta_by_ym

# %%
beta_by_ym.unstack(0)['AAPL']

# %% [markdown]
# GroupBy with hierarchical indexing
# ----------------------------------

# %%
tuples = zip(*[['bar', 'bar', 'baz', 'baz',
                'foo', 'foo', 'qux', 'qux'],
               ['one', 'two', 'one', 'two',
                'one', 'two', 'one', 'two']])
index = MultiIndex.from_tuples(tuples)
columns = MultiIndex.from_tuples([('A', 'cat'), ('B', 'dog'),
                                  ('B', 'cat'), ('A', 'dog')])
df = DataFrame(randn(8, 4), index=index, columns=columns)
df

# %%
df.groupby(level=0, axis=0).mean()

# %%
df.stack()

# %%
df.stack().mean(1).unstack()

# %%
# could also have done
df.groupby(level=1, axis=1).mean()
